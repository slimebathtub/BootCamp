# %% [markdown]
# ## 1) Hello, World
# **Mission**：
# 1. Print `Hello, World!`
# 2. create variable `name` and print `Hello, <name>!`

# %% [markdown]
# ## 2) `import` and calculation
# **Mission**：
# - use `math.sqrt` to calculate \(\sqrt{144}\)
# - use `statistics.mean` calculate the mean of the list `nums=[3,1,4,1,5]`

# %% [markdown]
# ## 3) Variable and list/Dictionary
#
# **Mission**：
# - create `numbers = [1,2,3,4,5]`
# - use **list** to print out the suare of the number
# - Create a dictionary to store everyone's age and name

# %%
age_name = {'Lee': 21}

print(age_name['Lee'])
# Out:
# 21

# %% [markdown]
# # 4) boolean and comparison operators
# Mission:
# - Return `True` if it is an even number
# - calculate BMI and seperate into different case
#     - BMI formula = weight(kg)/(height(m))<sup>2
# - or, calculate the leap year
#     - diviable by 4 but not 100
#     - diviable by 400

# %% [markdown]
# ## 5) `for` and `while`
# **Mission**：
# - use `for` to print out  `0 1 3 4 ... to 101`（no 2)
# - use `while` from `23` count to `1`

# %% [markdown]
# ## 6) Function
# **Mission**：
# - complete `power(base, exp=2)`
#     - function explain: calculate the power of the number
# - Complete `hallow_world(print)`
#     - function explain: print hallow_world
# - in the further challenge always use FUNCTION to finished the mission

# %%
# Out:
# hello world

# %% [markdown]
# ## 6) Comprehension
# **Mission**：
# - calculate the len form a list in one line
# - `lengths = [len(w) for w in words]`
# - `word_len = {w: len(w) for w in words}`

# %% [markdown]
# # 7) File I/O
# out put file to sepesict place
# - with open(path, "w"): `write`
#     - write several lines
#
# - with open(path, "r"): only `read`
#     - readlines
#
# - with open(path, "a): `append`
#
# - encoding="utf-8"

# %%
path = "hi.txt"

write_lines = ['Lee', 'Edgar', 'Goodmorning']

#with open(path, "a") as file:
#    for line in write_lines:
#        file.write(line+"\n")

with open(path, "r") as file:
    for line in file.readlines():
        lines += [line.strip()]
    print(lines)
# Out:
# ['Goodmorning', 'HiComtinueLee', 'Edgar', 'Goodmorning', 'Lee', 'Edgar', 'Goodmorning', 'Lee', 'Edgar', 'Goodmorning']
